# %%
import numpy as np
import time, os, sys
from urllib.parse import urlparse
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi'] = 300
from cellpose import utils, io
from PIL import Image
import cv2
import tools

my_data = "/home/keeganfl/Desktop/Math_612_project/05-10-2015/Height/"
save_path = "/home/keeganfl/Desktop/Math_612_project/05-10-2015/omnipose_height/"

# %% [markdown]
# ## Step 1:
# Create a list of files that contains the path for everything in your folder of images.

# %%
files = os.listdir(my_data)
for fichier in files[:]: # filelist[:] makes a copy of filelist.
    if not(fichier.endswith(".png")):
        files.remove(fichier)
        
# Sort files by timepoint
files.sort(key = tools.natural_keys)      

save_names = [save_path + file for file in files]
file_names = [my_data + file for file in files]

# %%
# view 1 image
img = io.imread(file_names[0])
plt.figure(figsize=(2,2))
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## Step 2:
# Running cellpose on every file within our data folder and saving the output to our save path.

# %%
# RUN CELLPOSE

from cellpose import models, io

# DEFINE CELLPOSE MODEL
# model_type='cyto' or model_type='nuclei'
model = models.Cellpose(gpu=False, model_type='bact_omni')

# define CHANNELS to run segementation on
# grayscale=0, R=1, G=2, B=3
# channels = [cytoplasm, nucleus]
# if NUCLEUS channel does not exist, set the second channel to 0
# channels = [0,0]
# IF ALL YOUR IMAGES ARE THE SAME TYPE, you can give a list with 2 elements
# channels = [0,0] # IF YOU HAVE GRAYSCALE
# channels = [2,3] # IF YOU HAVE G=cytoplasm and B=nucleus
# channels = [2,1] # IF YOU HAVE G=cytoplasm and R=nucleus

# or if you have different types of channels in each image
channels = [0,0]

# if diameter is set to None, the size of the cells is estimated on a per image basis
# you can set the average cell `diameter` in pixels yourself (recommended) 
# diameter can be a list or a single number for all images

# you can run all in a list e.g.
# >>> imgs = [io.imread(filename) in for filename in files]
# >>> masks, flows, styles, diams = model.eval(imgs, diameter=None, channels=channels)
# >>> io.masks_flows_to_seg(imgs, masks, flows, diams, files, channels)
# >>> io.save_to_png(imgs, masks, flows, files)

# or in a loop
for filename, savename in zip(file_names, save_names):
    img = io.imread(filename)
    masks, flows, styles, diams = model.eval(img, diameter=60, channels=channels, omni = True, invert = True)

    # save results so you can load in gui
    io.masks_flows_to_seg(img, masks, flows, diams, savename, channels)

    #save results as png
    io.save_to_png(img, masks, flows, savename)
# Out:
# dddddd 4
# yeh True True False 19.270852088928223
# connectivity 1
# dddddd 4
# yeh True True False 19.463255882263184
# connectivity 1
# dddddd 4
# yeh True True False 20.45906352996826
# connectivity 1
# dddddd 4
# yeh True True False 21.2397723197937
# connectivity 1
# dddddd 4
# yeh True True False 21.092631340026855
# connectivity 1
# dddddd 4
# yeh True True False 22.780086994171143
# connectivity 1
# dddddd 4
# yeh True True False 20.713684558868408
# connectivity 1
# dddddd 4
# yeh True True False 23.101823329925537
# connectivity 1
# dddddd 4
# yeh True True False 18.983569622039795
# connectivity 1
# dddddd 4
# yeh True True False 20.442017555236816
# connectivity 1
# dddddd 4
# yeh True True False 18.85107135772705
# connectivity 1
# dddddd 4
# yeh True True False 20.913602828979492
# connectivity 1
# dddddd 4
# yeh True True False 20.965125560760498
# connectivity 1
# dddddd 4
# yeh True True False 20.758897304534912
# connectivity 1

# %%
# DISPLAY RESULTS
from cellpose import plot

fig = plt.figure(figsize=(12,5))
plot.show_segmentation(fig, img, masks, flows[0], channels=channels)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Notes:
# Omnipose is great, but I am suffering from a bit of the infamous oversegmentation I have heard about...
#
# Also, it is far more likely to grab some weird little thing created from a graphical glitch and interpret it as a cell.
#
# Also Also, I cannot automatically calculate cell diameter with omnipose which is an absolute pain.
